# %% [markdown]
# # Day 22 — LSTM Sentiment Analysis
#
# This notebook demonstrates the complete workflow: dataset creation, vocabulary building, LSTM training, and inference.

# %%
from src.dataset import make_fallback_dataset, build_vocab
rows = make_fallback_dataset(20)
print(rows[:3])
vocab = build_vocab(rows)
print('Vocabulary size:', len(vocab))

# %% [markdown]
# ## Train the model
# Run the following from the project root if you want a full training run.

# %%
# !python -m src.train --epochs 5

# %% [markdown]
# ## Predict sentiment
# After training, the model can classify a new review.

# %%
from src.predict import predict

text = 'The movie was fantastic and I really enjoyed it.'
predict(text)
